# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess = cv2.imread(r"C:\Users\umut3\Desktop\Computer-Vision-with-Python\DATA\flat_chessboard.png")
plt.imshow(flat_chess)

# %%
found, corners = cv2.findChessboardCorners(flat_chess, (7,7))

# %%
found
# Out:
# True

# %%
corners
# Out:
# array([[[ 43.500004,  43.500004]],
#
#        [[ 87.5     ,  43.5     ]],
#
#        [[131.5     ,  43.5     ]],
#
#        [[175.5     ,  43.5     ]],
#
#        [[219.5     ,  43.5     ]],
#
#        [[263.5     ,  43.5     ]],
#
#        [[307.5     ,  43.5     ]],
#
#        [[ 43.499996,  87.50001 ]],
#
#        [[ 87.5     ,  87.5     ]],
#
#        [[131.5     ,  87.5     ]],
#
#        [[175.5     ,  87.5     ]],
#
#        [[219.5     ,  87.5     ]],
#
#        [[263.5     ,  87.5     ]],
#
#        [[307.5     ,  87.49999 ]],
#
#        [[ 43.500004, 131.5     ]],
#
#        [[ 87.5     , 131.5     ]],
#
#        [[131.5     , 131.5     ]],
#
#        [[175.5     , 131.5     ]],
#
#        [[219.5     , 131.5     ]],
#
#        [[263.5     , 131.5     ]],
#
#        [[307.5     , 131.5     ]],
#
#        [[ 43.499996, 175.5     ]],
#
#        [[ 87.5     , 175.5     ]],
#
#        [[131.5     , 175.5     ]],
#
#        [[175.5     , 175.5     ]],
#
# ...

# %%
cv2.drawChessboardCorners(flat_chess, (7,7), corners, found)
# Out:
# array([[[158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255],
#         ...,
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209]],
#
#        [[158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255],
#         ...,
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209]],
#
#        [[158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255],
#         ...,
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209]],
#
#        ...,
#
#        [[ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         ...,
#         [158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255]],
#
#        [[ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209],
#         ...,
#         [158, 206, 255],
#         [158, 206, 255],
#         [158, 206, 255]],
#
#        [[ 71, 139, 209],
#         [ 71, 139, 209],
#         [ 71, 139, 209],
# ...

# %%
plt.imshow(flat_chess)

# %%
grid = cv2.imread(r"C:\Users\umut3\Desktop\Computer-Vision-with-Python\DATA\dot_grid.png")
plt.imshow(grid)

# %%
found, corners = cv2.findCirclesGrid(grid, (10,10))

# %%
found
# Out:
# True

# %%
cv2.drawChessboardCorners(grid, (10,10), corners, found)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(grid)
